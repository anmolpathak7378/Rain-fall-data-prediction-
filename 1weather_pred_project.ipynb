# %%
#here is a clear visulization of rain-fall data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
from sklearn.linear_model import LinearRegression

# %%
#now will import the data 

data = pd.read_csv("austin_weather.csv")
data.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
#   SeaLevelPressureAvgInches SeaLevelPressureLowInches VisibilityHighMiles  \
# 0                     29.68                     29.59                  10
# 1                     30.13                     29.87                  10
# 2                     30.49                     30.41                  10
# 3                     30.45                      30.3                  10
# 4                     30.33                     30.27                  10
#
#   VisibilityAvgMiles VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                  7                  2          20          4          31
# 1                 10                  5          16          6          25
# 2                 10                 10           8          3          12
# 3                 10                  7          12          4          20
# 4                 10                  7          10          2          16
#
#   PrecipitationSumInches               Events
# 0                   0.46  Rain , Thunderstorm
# 1                      0
# 2                      0
# 3                      0
# 4                      T
#
# [5 rows x 21 columns]

# %%
#now remove unnecessary columns

data = data.drop(["Date", "Events"], axis=1)

#remove null values

# %%
data = data.replace("T", 0)

# %%
data = data.replace("-", 0)

# %%
data
# Out:
#       TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0            74        60        45            67           49           43
# 1            56        48        39            43           36           28
# 2            58        45        32            31           27           23
# 3            61        46        31            36           28           21
# 4            58        50        41            44           40           36
# ...         ...       ...       ...           ...          ...          ...
# 1314        103        89        75            71           67           61
# 1315        105        91        76            71           64           55
# 1316        107        92        77            72           64           55
# 1317        106        93        79            70           68           63
# 1318         99        88        77            66           61           54
#
#      HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 0                     93                 75                 57
# 1                     93                 68                 43
# 2                     76                 52                 27
# 3                     89                 56                 22
# 4                     86                 71                 56
# ...                  ...                ...                ...
# 1314                  82                 54                 25
# 1315                  87                 54                 20
# 1316                  82                 51                 19
# 1317                  69                 48                 27
# 1318                  64                 43                 22
#
#      SeaLevelPressureHighInches SeaLevelPressureAvgInches  \
# 0                         29.86                     29.68
# 1                         30.41                     30.13
# 2                         30.56                     30.49
# 3                         30.56                     30.45
# 4                         30.41                     30.33
# ...                         ...                       ...
# 1314                      30.04                     29.97
# 1315                      29.97                      29.9
# 1316                      29.91                     29.86
# 1317                      29.96                     29.91
# 1318                      30.04                     29.97
#
#      SeaLevelPressureLowInches VisibilityHighMiles VisibilityAvgMiles  \
# 0                        29.59                  10                  7
# 1                        29.87                  10                 10
# 2                        30.41                  10                 10
# 3                         30.3                  10                 10
# 4                        30.27                  10                 10
# ...                        ...                 ...                ...
# 1314                     29.88                  10                 10
# 1315                     29.81                  10                 10
# 1316                     29.79                  10                 10
# 1317                     29.87                  10                 10
# 1318                     29.91                  10                 10
#
#      VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                     2          20          4          31
# 1                     5          16          6          25
# 2                    10           8          3          12
# 3                     7          12          4          20
# 4                     7          10          2          16
# ...                 ...         ...        ...         ...
# 1314                 10          12          5          21
# 1315                 10          14          5          20
# 1316                 10          12          4          17
# 1317                 10          13          4          20
# 1318                 10          12          4          20
#
#      PrecipitationSumInches
# 0                      0.46
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 1314                      0
# 1315                      0
# 1316                      0
# 1317                      0
# 1318                      0
#
# [1319 rows x 19 columns]

# %%
#convert this data 
data.to_csv("weather_final.csv")

# %%
#import this final data

data = pd.read_csv("weather_final.csv")
data
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  TempHighF  TempAvgF  TempLowF  \
# 0                0             0           0         74        60        45
# 1                1             1           1         56        48        39
# 2                2             2           2         58        45        32
# 3                3             3           3         61        46        31
# 4                4             4           4         58        50        41
# ...            ...           ...         ...        ...       ...       ...
# 1314          1314          1314        1314        103        89        75
# 1315          1315          1315        1315        105        91        76
# 1316          1316          1316        1316        107        92        77
# 1317          1317          1317        1317        106        93        79
# 1318          1318          1318        1318         99        88        77
#
#       DewPointHighF  DewPointAvgF  DewPointLowF  HumidityHighPercent  ...  \
# 0                67            49            43                   93  ...
# 1                43            36            28                   93  ...
# 2                31            27            23                   76  ...
# 3                36            28            21                   89  ...
# 4                44            40            36                   86  ...
# ...             ...           ...           ...                  ...  ...
# 1314             71            67            61                   82  ...
# 1315             71            64            55                   87  ...
# 1316             72            64            55                   82  ...
# 1317             70            68            63                   69  ...
# 1318             66            61            54                   64  ...
#
#       SeaLevelPressureHighInches  SeaLevelPressureAvgInches  \
# 0                          29.86                      29.68
# 1                          30.41                      30.13
# 2                          30.56                      30.49
# 3                          30.56                      30.45
# 4                          30.41                      30.33
# ...                          ...                        ...
# 1314                       30.04                      29.97
# 1315                       29.97                      29.90
# 1316                       29.91                      29.86
# 1317                       29.96                      29.91
# 1318                       30.04                      29.97
#
#       SeaLevelPressureLowInches  VisibilityHighMiles  VisibilityAvgMiles  \
# 0                         29.59                   10                   7
# 1                         29.87                   10                  10
# 2                         30.41                   10                  10
# 3                         30.30                   10                  10
# 4                         30.27                   10                  10
# ...                         ...                  ...                 ...
# 1314                      29.88                   10                  10
# 1315                      29.81                   10                  10
# 1316                      29.79                   10                  10
# 1317                      29.87                   10                  10
# 1318                      29.91                   10                  10
#
#       VisibilityLowMiles  WindHighMPH  WindAvgMPH  WindGustMPH  \
# 0                      2           20           4           31
# 1                      5           16           6           25
# 2                     10            8           3           12
# 3                      7           12           4           20
# 4                      7           10           2           16
# ...                  ...          ...         ...          ...
# 1314                  10           12           5           21
# 1315                  10           14           5           20
# 1316                  10           12           4           17
# 1317                  10           13           4           20
# 1318                  10           12           4           20
#
#       PrecipitationSumInches
# 0                       0.46
# 1                       0.00
# 2                       0.00
# 3                       0.00
# 4                       0.00
# ...                      ...
# 1314                    0.00
# 1315                    0.00
# 1316                    0.00
# 1317                    0.00
# 1318                    0.00
#
# [1319 rows x 22 columns]

# %%
#make labels
X = data.drop(["PrecipitationSumInches"], axis= 1)

# %%
Y = data["PrecipitationSumInches"]

# %%
#reshape the value of Y in 2d vector

Y = Y.values.reshape(-1, 1)
Y
# Out:
# array([[0.46],
#        [0.  ],
#        [0.  ],
#        ...,
#        [0.  ],
#        [0.  ],
#        [0.  ]])

# %%
#now we will take any random day for prediction
day_index = 798
days = [i for i in range(Y.size)]
days

# %%
#initialize linier reg

clf = LinearRegression()
clf.fit(X,  Y)
# Out:
# LinearRegression()

# %%
#plot the graphs

plt.scatter(days, Y, color = "green")
plt.scatter(days[day_index], Y[day_index], color = "red")
plt.scatter(days[200], Y[200], color = "blue")

plt.title("the precipitation level")
plt.xlabel("days")
plt.ylabel("PrecipitationSumInches")
plt.show()

# %%
x_vis = X.filter(["DewPointHighF", "TempAvgF", "VisibilityAvgMiles", "WindAvgMPH"])

# %%
x_vis = X.filter(["DewPointHighF", "TempAvgF", "VisibilityAvgMiles", "WindAvgMPH"])

print("adding subplot - the precipitation vs attributes")

for i in range(x_vis.columns.size):
    plt.subplot(2, 2, i + 1)  # 2x2 grid for 4 plots
    plt.scatter(days, x_vis[x_vis.columns[i]], color="yellow")
    plt.scatter(days[day_index], x_vis[x_vis.columns[i]][day_index], color="red")
    plt.title(x_vis.columns[i])

plt.xlabel("days")
plt.ylabel("precipitation in inch")
plt.tight_layout()
plt.show()
# Out:
# adding subplot - the precipitation vs attributes
